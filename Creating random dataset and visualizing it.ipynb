# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np

# %%
#create a dataframe
#date_range is predefined keyword in pandas
ds=pd.DataFrame(np.random.rand(10,4),index=pd.date_range('1/1/2000',periods=10),columns=list('ABCD'))

# %%
#ds local variable
#pd pandas variable
#x - numpy random range
#y - index year range -----specify the time period also i.e, 10 months
#columns - different lines in the graph below
ds.plot()
# Out:
# <AxesSubplot:>

# %%
sns.barplot(data=ds)
# Out:
# <AxesSubplot:>

# %%
ds.plot.bar()
# Out:
# <AxesSubplot:>

# %%
ds=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])

# %%
ds.plot.bar()
# Out:
# <AxesSubplot:>

# %%
#print/plot a stacked bar graph
ds=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])
ds.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
#to plot bar graph horizontally
ds=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])
ds.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %%
#box
ds=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])
ds.plot.box()
# Out:
# <AxesSubplot:>

# %%
#area plot
ds.plot.area()
# Out:
# <AxesSubplot:>

# %%
#scatterplot
#GIVE ARGUMENTS x and y for scatterplot
ds=pd.DataFrame(np.random.rand(40,4),columns=['A','B','C','D'])
ds.plot.scatter(x='A',y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
#new data frame of 1 column
data=[1,2,3,4,5]

# %%
data
# Out:
# [1, 2, 3, 4, 5]

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
df[0]
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: 0, dtype: int64

# %%
df[0][2]
# Out:
# 3

# %%
#new dataframe of 2 columns
data1=['Arun',94],['Neelu',80],['Ryan',96],['Chris',77]

# %%
df=pd.DataFrame(data1)

# %%
df
# Out:
#        0   1
# 0   Arun  94
# 1  Neelu  80
# 2   Ryan  96
# 3  Chris  77

# %%
#display ryan 96 - use iloc
df.iloc[2]
# Out:
# 0    Ryan
# 1      96
# Name: 2, dtype: object

# %%
df[0:][2:3]
# Out:
#       0   1
# 2  Ryan  96

# %%
#rename columns
df=pd.DataFrame(data1,columns=['Name','Age'])

# %%
df
# Out:
#     Name  Age
# 0   Arun   94
# 1  Neelu   80
# 2   Ryan   96
# 3  Chris   77

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='Name',y='Age')
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Age'>

# %%
#create data frame with 3 columns
data2=['Arun',94,'CSE'],['Neelu',80,'IT'],['Ryan',96,'IT'],['Chris',77,'CSE']

# %%
df=pd.DataFrame(data2)

# %%
df
# Out:
#        0   1    2
# 0   Arun  94  CSE
# 1  Neelu  80   IT
# 2   Ryan  96   IT
# 3  Chris  77  CSE

# %%
df=pd.DataFrame(data2,columns=['Name','Age','Department'])
df
# Out:
#     Name  Age Department
# 0   Arun   94        CSE
# 1  Neelu   80         IT
# 2   Ryan   96         IT
# 3  Chris   77        CSE

# %%
#another way to create new data frame
data3={'Name':['Andrew','Bishop','Charles','Dickens','Enzo'],'Age':[21,23,22,25,24],'Department':['CSE','IT','CSD','CSBS','ADS']}

# %%
data3
# Out:
# {'Name': ['Andrew', 'Bishop', 'Charles', 'Dickens', 'Enzo'],
#  'Age': [21, 23, 22, 25, 24],
#  'Department': ['CSE', 'IT', 'CSD', 'CSBS', 'ADS']}

# %%
df=pd.DataFrame(data3)

# %%
df
# Out:
#       Name  Age Department
# 0   Andrew   21        CSE
# 1   Bishop   23         IT
# 2  Charles   22        CSD
# 3  Dickens   25       CSBS
# 4     Enzo   24        ADS

# %%
#to change row number 0,1,2,3,4 in above example
df=pd.DataFrame(data3,columns=[],index=['First','Second','Third','Fourth','Fifth'])

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [First, Second, Third, Fourth, Fifth]

# %%
#to change row number 0,1,2,3,4 in above example
df=pd.DataFrame(data3,columns=['Name','Age','Department'],index=['First','Second','Third','Fourth','Fifth'])

# %%
df
# Out:
#            Name  Age Department
# First    Andrew   21        CSE
# Second   Bishop   23         IT
# Third   Charles   22        CSD
# Fourth  Dickens   25       CSBS
# Fifth      Enzo   24        ADS

# %%
df.plot()
# Out:
# <AxesSubplot:>
